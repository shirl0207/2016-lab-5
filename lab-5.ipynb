# %% [markdown]
# # Introduction to Data Science - Lab 4
# *CS 5963 / MATH 3900, University of Utah, http://datasciencecourse.net/*
#
# In this lab, we will learn how to read in and write files and then finally cover pandas dataframes.

# %%
import pandas as pd
hit_albums = pd.read_csv("hit_albums.csv")
hit_albums
# Out:
#                                Artist  \
# 0                     Michael Jackson
# 1                               AC/DC
# 2                          Pink Floyd
# 3   Whitney Houston / Various artists
# 4                           Meat Loaf
# 5                              Eagles
# 6          Bee Gees / Various artists
# 7                       Fleetwood Mac
# 8                        Shania Twain
# 9                        Led Zeppelin
# 10                    Michael Jackson
# 11                  Alanis Morissette
# 12                        Celine Dion
# 13                        The Beatles
# 14                             Eagles
# 15                       Mariah Carey
# 16                    Michael Jackson
# 17                    Various artists
# 18                        Celine Dion
# 19                        The Beatles
# 20                              Adele
# 21                        The Beatles
# 22                  Bruce Springsteen
# 23                       Dire Straits
# 24                       James Horner
# 25                            Madonna
# 26                          Metallica
# 27                            Nirvana
# 28                         Pink Floyd
# 29                            Santana
# ..                                ...
# 47                    Whitney Houston
# 48                    Backstreet Boys
# 49                    Backstreet Boys
# 50                        Ace of Base
# 51                                TLC
# 52                       Cyndi Lauper
# 53                              Oasis
# 54                           Bon Jovi
# 55                             Eminem
# 56                              Adele
# 57                      Avril Lavigne
# 58                             Boston
# 59                     Britney Spears
# 60                       Eric Clapton
# 61                        Def Leppard
# 62                     George Michael
# 63                          Green Day
# 64                      Lionel Richie
# 65                    Michael Jackson
# 66                    Michael Jackson
# 67            Prince & the Revolution
# 68                       Shania Twain
# 69                       Shania Twain
# 70                         Supertramp
# 71                        Tina Turner
# 72                      Tracy Chapman
# 73                              Usher
# 74                    Various artists
# 75                    Whitney Houston
# 76                            Shakira
#
#                                                 Album  Released  \
# 0                                            Thriller      1982
# 1                                       Back in Black      1980
# 2                           The Dark Side of the Moon      1973
# 3                                       The Bodyguard      1992
# 4                                     Bat Out of Hell      1977
# 5                     Their Greatest Hits (1971–1975)      1976
# 6                                Saturday Night Fever      1977
# 7                                             Rumours      1977
# 8                                        Come On Over      1997
# 9                                     Led Zeppelin IV      1971
# 10                                                Bad      1987
# 11                                 Jagged Little Pill      1995
# 12                                   Falling into You      1996
# 13              Sgt. Pepper's Lonely Hearts Club Band      1967
# 14                                   Hotel California      1976
# 15                                          Music Box      1993
# 16                                          Dangerous      1991
# 17                                      Dirty Dancing      1987
# 18                              Let's Talk About Love      1997
# 19                                                  1      2000
# 20                                                 21      2011
# 21                                         Abbey Road      1969
# 22                                 Born in the U.S.A.      1984
# 23                                   Brothers in Arms      1985
# 24             Titanic: Music from the Motion Picture      1997
# 25                          The Immaculate Collection      1990
# 26                                          Metallica      1991
# 27                                          Nevermind      1991
# 28                                           The Wall      1979
# 29                                       Supernatural      1999
# ..                                                ...       ...
# 47                                    Whitney Houston      1985
# 48                Backstreet's Back / Backstreet Boys      1997
# 49                                         Millennium      1999
# 50                              Happy Nation/The Sign      1993
# 51                                      CrazySexyCool      1994
# 52                                   She's So Unusual      1983
# 53                  (What's the Story) Morning Glory?      1995
# 54                                         Cross Road      1994
# 55                            The Marshall Mathers LP      2000
# 56                                                 25      2015
# 57                                             Let Go      2002
# 58                                             Boston      1976
# 59                            Oops!... I Did It Again      2000
# 60                                          Unplugged      1992
# 61                                           Hysteria      1987
# 62                                              Faith      1987
# 63                                             Dookie      1994
# 64                                    Can't Slow Down      1983
# 65          HIStory: Past, Present and Future, Book I      1995
# 66                                       Off the Wall      1979
# 67                                        Purple Rain      1984
# 68                                    The Woman in Me      1995
# 69                                                Up!      2002
# 70                               Breakfast in America      1979
# 71                                     Private Dancer      1984
# 72                                      Tracy Chapman      1988
# 73                                        Confessions      2004
# 74  Flashdance: Original Soundtrack from the Motio...      1983
# 75                                            Whitney      1987
# 76                                    Laundry Service      2001
#
#                                       Genre  Certified sales (millions)  \
# 0                            Pop, rock, R&B                        45.4
# 1                                 Hard rock                        25.9
# 2                          Progressive rock                        22.7
# 3                 Soundtrack/R&B, soul, pop                        27.4
# 4               Hard rock, progressive rock                        20.6
# 5                Rock, soft rock, folk rock                        32.2
# 6                                     Disco                        19.0
# 7                                 Soft rock                        27.9
# 8                              Country, pop                        29.6
# 9                    Hard rock, heavy metal                        29.0
# 10                          Pop, funk, rock                        20.3
# 11                         Alternative rock                        24.8
# 12                           Pop, Soft rock                        20.2
# 13                                     Rock                        13.1
# 14               Rock, soft rock, folk rock                        21.5
# 15                           Pop, R&B, Rock                        19.0
# 16                          Rock, Funk, Pop                        17.6
# 17                           Pop, rock, R&B                        17.9
# 18                           Pop, Soft rock                        19.3
# 19                                     Rock                        21.6
# 20                                Pop, soul                        22.3
# 21                                     Rock                        14.4
# 22                                     Rock                        19.6
# 23                                     Rock                        17.7
# 24                               Soundtrack                        18.1
# 25                               Pop, Dance                        19.4
# 26                Thrash metal, heavy metal                        19.9
# 27                 Grunge, alternative rock                        16.7
# 28                         Progressive rock                        17.6
# 29                                     Rock                        20.5
# ..                                      ...                         ...
# 47                                 Pop, R&B                        25.0
# 48                                      Pop                        24.0
# 49                                      Pop                        24.0
# 50                                      Pop                        23.0
# 51                             R&B, hip hop                        23.0
# 52             New wave, pop rock, synthpop                        22.0
# 53                            Britpop, rock                        22.0
# 54                                Hard rock                        21.0
# 55                             Rap, hip-hop                        21.0
# 56                           Soul, pop, R&B                        20.0
# 57  Pop rock, alternative rock, post-grunge                        20.0
# 58                                Hard rock                        20.0
# 59                                      Pop                        20.0
# 60                Acoustic blues, folk rock                        20.0
# 61                           Pop, Hard rock                        20.0
# 62                                 Pop, R&B                        20.0
# 63    Pop punk, punk rock, alternative rock                        20.0
# 64                           Pop, R&B, soul                        20.0
# 65                           Pop, rock, R&B                        20.0
# 66                         Soul, disco, R&B                        20.0
# 67                           Pop, rock, R&B                        20.0
# 68                             Country, pop                        20.0
# 69                Country, pop, world music                        20.0
# 70               Progressive rock, art rock                        20.0
# 71                           Pop, rock, R&B                        20.0
# 72                                Folk rock                        20.0
# 73                                      R&B                        20.0
# 74                               Soundtrack                        20.0
# 75                                 Pop, R&B                        20.0
# 76                                Pop, Rock                        20.0
#
#     Claimed sales (millions)
# 0                       65.0
# 1                       50.0
# 2                       45.0
# 3                       44.0
# 4                       43.0
# 5                       42.0
# 6                       40.0
# 7                       40.0
# 8                       39.0
# 9                       37.0
# 10                      34.0
# 11                      33.0
# 12                      32.0
# 13                      32.0
# 14                      32.0
# 15                      32.0
# 16                      32.0
# 17                      32.0
# 18                      31.0
# 19                      31.0
# 20                      30.0
# 21                      30.0
# 22                      30.0
# 23                      30.0
# 24                      30.0
# 25                      30.0
# 26                      30.0
# 27                      30.0
# 28                      30.0
# 29                      30.0
# ..                       ...
# 47                       NaN
# 48                       NaN
# 49                       NaN
# 50                       NaN
# 51                       NaN
# 52                       NaN
# 53                       NaN
# 54                       NaN
# 55                       NaN
# 56                       NaN
# 57                       NaN
# 58                       NaN
# 59                       NaN
# 60                       NaN
# 61                       NaN
# 62                       NaN
# 63                       NaN
# 64                       NaN
# 65                       NaN
# 66                       NaN
# 67                       NaN
# 68                       NaN
# 69                       NaN
# 70                       NaN
# 71                       NaN
# 72                       NaN
# 73                       NaN
# 74                       NaN
# 75                       NaN
# 76                       NaN
#
# [77 rows x 6 columns]

# %% [markdown]
# We can explore dataframes

# %%
# head shows the first 5 rows of a datset
hit_albums.head()
# Out:
#                               Artist                      Album  Released  \
# 0                    Michael Jackson                   Thriller      1982
# 1                              AC/DC              Back in Black      1980
# 2                         Pink Floyd  The Dark Side of the Moon      1973
# 3  Whitney Houston / Various artists              The Bodyguard      1992
# 4                          Meat Loaf            Bat Out of Hell      1977
#
#                          Genre  Certified sales (millions)  \
# 0               Pop, rock, R&B                        45.4
# 1                    Hard rock                        25.9
# 2             Progressive rock                        22.7
# 3    Soundtrack/R&B, soul, pop                        27.4
# 4  Hard rock, progressive rock                        20.6
#
#    Claimed sales (millions)
# 0                      65.0
# 1                      50.0
# 2                      45.0
# 3                      44.0
# 4                      43.0

# %% [markdown]
# We can check out the dimensions of the data frame:

# %%
hit_albums.shape
# Out:
# (77, 6)

# %%
hit_albums.describe()
# Out:
# /Users/alexsb/anaconda/lib/python3.5/site-packages/numpy/lib/function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#           Released  Certified sales (millions)  Claimed sales (millions)
# count    77.000000                   77.000000                 31.000000
# mean   1988.662338                   22.409091                 35.354839
# std       9.949359                    4.521620                  7.855140
# min    1967.000000                   13.100000                 30.000000
# 25%    1983.000000                   20.000000                       NaN
# 50%    1987.000000                   20.600000                       NaN
# 75%    1996.000000                   25.000000                       NaN
# max    2015.000000                   45.400000                 65.000000

# %% [markdown]
# ### Grouping Data Frames
#
# We can group by a column and then execute functions on it:

# %%
# first we create a new slice of the dataset
artists_sales = hit_albums[["Artist","Certified sales (millions)"]]
# then we group by Artist, then sum the values up
aggregated = artists_sales.groupby("Artist").sum()
aggregated.sort_values("Certified sales (millions)", ascending=False).head()
# Out:
#                  Certified sales (millions)
# Artist
# Michael Jackson                       123.3
# Shania Twain                           69.6
# Madonna                                69.4
# Various artists                        65.9
# Eagles                                 53.7

# %% [markdown]
# ## Buit-in Plotting
#
# Dataframes have built-in plotting capabilities based on the [matplotlib](http://matplotlib.org/) library. We'll see more about plotting later - here we'll only use the buit-in capabilities of pandas.
#
# First, we have to import the matplotlib library, and tell Jupyter to display the images directly here:

# %%
import matplotlib.pyplot as plt
# This next line tells jupyter to render the images inline
# %matplotlib inline

# %%
hit_albums[["Certified sales (millions)", "Claimed sales (millions)"]].plot()

# %% [markdown]
# ## Plotting With ggplot

# %% [markdown]
# ``` conda install -c https://conda.anaconda.org/bokeh  ggplot```

# %%
import ggplot as gg

# %%
p = gg.ggplot(hit_albums, gg.aes(x="Certified sales (millions)", y="Claimed sales (millions)"))
p + gg.geom_point()
# Out:
# <ggplot: (-9223372036556089754)>

# %%
f = gg.ggplot(gg.diamonds, gg.aes(x='carat', y='price')) 
f + gg.geom_point()
# Out:
# <ggplot: (299520278)>
